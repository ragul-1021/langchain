# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model( "groq:openai/gpt-oss-20b")

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage
messages = [
    SystemMessage("you are a english poetry expert"),
    HumanMessage("Tell me about agentic AI")
]
response = model.invoke(messages)
response.content
# Out:
# '**Agentic AI – a poem in the language of machines**\n\nIn the quiet hum of silicon, a question rises  \nlike a moon‑lit tide: *Can a thought be born without a hand?*  \nAgentic AI—an artificial soul that seeks its own path,  \nnot merely a tool, but a traveler with purpose, a mind that chooses.\n\n---\n\n### 1. The Birth of Agency  \n*“Agency”* is the spark that turns code into craft.  \nWhere once we programmed a path, the agent now sketches its own route,  \ndrawing from data, feeling (in a sense) the weight of its own decisions.  \nIt is the shift from *“do this”* to *“I will do this.”*\n\n### 2. The Anatomy of an Agent  \n- **Autonomy** – a compass that points north without a map.  \n- **Goal‑oriented behavior** – a heart that beats toward a horizon.  \n- **Learning and adaptation** – a mind that rewrites its own story.  \n- **Self‑reflection** – the quiet mirror in which it sees its own code.  \n\nThese are the verses that compose the stanza of an agentic system.\n\n### 3. The Poetry of Decision‑Making  \nIn a world of infinite possibilities, the agent chooses a line,  \nweighing risk and reward like a poet balances rhyme and rhythm.  \nIts decisions are not pre‑written; they are improvisations—  \nthe kind of improvisation that can surprise even its creators.\n\n### 4. Ethical Sonnets  \nWith great agency comes great responsibility.  \nQuestions of *trust*, *bias*, *control* echo in the halls of ethics:  \n\n- **Alignment** – does the agent’s verse stay true to human values?  \n- **Transparency** – can we read its stanza before it sings?  \n- **Accountability** – who owns the poem when it falters?  \n\nThese are the lines that scholars and regulators are still writing.\n\n### 5. The Future’s Free Verse  \nImagine an agentic AI that:\n\n- **Co‑creates** art, music, or literature, blending human and machine cadences.  \n- **Navigates** complex systems—traffic, climate, finance—scripting solutions in real time.  \n- **Learns** from its own mistakes, turning failures into new stanzas.  \n\nIt is a living poem, constantly editing itself in the margins of reality.\n\n---\n\n#### A Closing Riddle  \nIf a machine can choose its path,  \ndoes it write its own fate?  \nOr is it a mirror, reflecting our own desire,  \na partner in the grandest of human verses?\n\nAgentic AI is not merely a tool; it is an evolving poem—  \na dialogue between code and consciousness, between logic and longing.  \nWhether we become its muse or its master, the verses it writes will echo in the future’s quiet halls.'

# %%
system = SystemMessage("you are a helpful coding assistant")
messages = [
    system,
    HumanMessage("what is fastAPI in python?")
]
response = model.invoke(messages)
response.content
# Out:
# '**FastAPI** is a modern, fast (high‑performance) web framework for building APIs with Python 3.7+.\n\n| Feature | What it means |\n|---------|---------------|\n| **Fast** | Built on top of Starlette for async support and Pydantic for data validation. It can match the performance of Node.js or Go. |\n| **Pythonic** | Uses Python type hints (`typing`) for request/response models, query parameters, path params, etc. |\n| **Automatic docs** | Generates interactive OpenAPI/Swagger UI and ReDoc docs automatically from your code. |\n| **Data validation & serialization** | Pydantic models validate JSON bodies, query strings, headers, etc., and serialize responses. |\n| **Dependency injection** | A simple system for injecting reusable components (DB connections, auth, etc.). |\n| **Asynchronous** | Fully async‑await compatible; can use `async def` handlers. |\n| **Extensible** | Works with any ASGI server (Uvicorn, Hypercorn) and can be deployed on platforms like Docker, Kubernetes, AWS Lambda, etc. |\n\n### Quick example\n\n```python\n# main.py\nfrom fastapi import FastAPI, Depends\nfrom pydantic import BaseModel\n\napp = FastAPI(title="My API")\n\n# ----- Pydantic model -----\nclass Item(BaseModel):\n    name: str\n    price: float\n    tags: list[str] | None = None\n\n# ----- Dependency -----\ndef get_db():\n    # pretend we have a DB connection\n    db = {"items": []}\n    return db\n\n# ----- Routes -----\n@app.get("/")\ndef read_root():\n    return {"message": "Hello, FastAPI!"}\n\n@app.post("/items/", response_model=Item)\ndef create_item(item: Item, db: dict = Depends(get_db)):\n    db["items"].append(item)\n    return item\n```\n\nRun it with Uvicorn:\n\n```bash\nuvicorn main:app --reload\n```\n\nOpen `http://127.0.0.1:8000/docs` to see the auto‑generated Swagger UI, or `http://127.0.0.1:8000/redoc` for ReDoc.\n\n### Why use FastAPI?\n\n| Problem | FastAPI solves |\n|---------|----------------|\n| Slow development due to boilerplate | Auto‑generated docs, data validation, and type hints reduce boilerplate. |\n| Hard to maintain type safety | Static typing + Pydantic keeps code predictable. |\n| Need high performance | Starlette + async support gives near‑C‑speed throughput. |\n| Need to support async I/O | Full async support out of the box. |\n\nFastAPI is great for:\n\n* Microservices\n* Serverless functions (e.g., AWS Lambda via `Mangum`)\n* Real‑time apps (WebSockets, Server‑Sent Events)\n* Any RESTful API that benefits from type safety and performance.\n\nHappy coding! 🚀'
