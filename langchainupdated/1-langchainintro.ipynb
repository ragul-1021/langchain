# %%
### langchain Version V1
import langchain 
langchain.__version__
# Out:
# '1.4.0'

# %%
from dotenv import load_dotenv
import os

load_dotenv()

from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."

agent = create_agent(
    model="gpt-4o-mini",
    tools=[get_weather],
    system_prompt="You are a helpful assistant."
)

agent

# %%
agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "What is the weather like in New York?"
        }
    ]
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 google_model = ChatGoogleGenerativeAI(
#       2     model="gemini-2.0-flash",
#       3     temperature=0
#       4 )
#
# NameError: name 'ChatGoogleGenerativeAI' is not defined

# %%
from langchain_openai import OpenAI
model = OpenAI(model="gpt-5")
response = model.invoke("Hi there!")
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 from langchain_openai import OpenAI
#       2 model = OpenAI(model="gpt-5")
# ----> 3 response = model.invoke("Hi there!")
#       4 response
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\llms.py:384, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     373 @override
#     374 def invoke(
#     375     self,
#    (...)    380     **kwargs: Any,
#     381 ) -> str:
#     382     config = ensure_config(config)
#     383     return (
# --> 384         self.generate_prompt(
#     385             [self._convert_input(input)],
#     386             stop=stop,
#     387             callbacks=config.get("callbacks"),
#     388             tags=config.get("tags"),
#     389             metadata=config.get("metadata"),
#     390             run_name=config.get("run_name"),
#     391             run_id=config.pop("run_id", None),
#     392             **kwargs,
#     393         )
#     394         .generations[0][0]
#     395         .text
#     396     )
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\llms.py:801, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     792 @override
#     793 def generate_prompt(
#     794     self,
#    (...)    798     **kwargs: Any,
#     799 ) -> LLMResult:
#     800     prompt_strings = [p.to_string() for p in prompts]
# --> 801     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1031, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1012 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1013     run_managers = [
#    1014         callback_manager.on_llm_start(
#    1015             self._serialized,
#    (...)   1029         )
#    1030     ]
# -> 1031     return self._generate_helper(
#    1032         prompts,
#    1033         stop,
#    1034         run_managers,
#    1035         new_arg_supported=bool(new_arg_supported),
#    1036         **kwargs,
#    1037     )
#    1038 if len(missing_prompts) > 0:
#    1039     run_managers = [
#    1040         callback_managers[idx].on_llm_start(
#    1041             self._serialized,
#    (...)   1048         for idx in missing_prompt_idxs
#    1049     ]
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\llms.py:827, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     816 def _generate_helper(
#     817     self,
#     818     prompts: list[str],
#    (...)    823     **kwargs: Any,
#     824 ) -> LLMResult:
#     825     try:
#     826         output = (
# --> 827             self._generate(
#     828                 prompts,
#     829                 stop=stop,
#     830                 # TODO: support multiple run managers
#     831                 run_manager=run_managers[0] if run_managers else None,
#     832                 **kwargs,
#     833             )
#     834             if new_arg_supported
#     835             else self._generate(prompts, stop=stop)
#     836         )
#     837     except BaseException as e:
#     838         for run_manager in run_managers:
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\langchain_openai\llms\base.py:510, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     494     choices.append(
#     495         {
#     496             "text": generation.text,
#    (...)    507         }
#     508     )
#     509 else:
# --> 510     response = self.client.create(prompt=_prompts, **params)
#     511     if not isinstance(response, dict):
#     512         # V1 client returns the response in an PyDantic object instead of
#     513         # dict. For the transition period, we deep convert it to dict.
#     514         response = response.model_dump()
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\openai\resources\completions.py:555, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     526 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     527 def create(
#     528     self,
#    (...)    553     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#     554 ) -> Completion | Stream[Completion]:
# --> 555     return self._post(
#     556         "/completions",
#     557         body=maybe_transform(
#     558             {
#     559                 "model": model,
#     560                 "prompt": prompt,
#     561                 "best_of": best_of,
#     562                 "echo": echo,
#     563                 "frequency_penalty": frequency_penalty,
#     564                 "logit_bias": logit_bias,
#     565                 "logprobs": logprobs,
#     566                 "max_tokens": max_tokens,
#     567                 "n": n,
#     568                 "presence_penalty": presence_penalty,
#     569                 "seed": seed,
#     570                 "stop": stop,
#     571                 "stream": stream,
#     572                 "stream_options": stream_options,
#     573                 "suffix": suffix,
#     574                 "temperature": temperature,
#     575                 "top_p": top_p,
#     576                 "user": user,
#     577             },
#     578             completion_create_params.CompletionCreateParamsStreaming
#     579             if stream
#     580             else completion_create_params.CompletionCreateParamsNonStreaming,
#     581         ),
#     582         options=make_request_options(
#     583             extra_headers=extra_headers,
#     584             extra_query=extra_query,
#     585             extra_body=extra_body,
#     586             timeout=timeout,
#     587             security={"bearer_auth": True},
#     588         ),
#     589         cast_to=Completion,
#     590         stream=stream or False,
#     591         stream_cls=Stream[Completion],
#     592     )
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1359     warnings.warn(
#    1360         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1361         "Please pass raw bytes via the `content` parameter instead.",
#    1362         DeprecationWarning,
#    1363         stacklevel=2,
#    1364     )
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Downloads\langchainupdated\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1138             err.response.read()
#    1140         log.debug("Re-raising status error")
# -> 1141         raise self._make_status_error_from_response(err.response) from None
#    1143     break
#    1145 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
import os
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-3.7-flash")
response = model.invoke("Hi there!")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.7-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0bccf-5681-7a50-91e1-160acbda1c7c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4, 'output_tokens': 166, 'total_tokens': 170, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 157}})
